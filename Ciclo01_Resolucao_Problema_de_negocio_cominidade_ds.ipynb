# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/data-analytics-python/blob/master/Ciclo01_Resolucao_Problema_de_negocio_cominidade_ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bibliotecas-aula comunidade DS
#resolvendo o problema do negocio
import pandas as pd
import numpy as np
data = pd.read_csv('/content/AB_NYC_2019.csv')
display(data)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
display(data.head(10))
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# Calcular a média de todos os valores de aluguel da cidade de Nova
# York.

# %%
#respondendo essa pergunta
data_aluguel_preco = data.loc[:,'price']
display(data_aluguel_preco)
# Out:
# 0     149
# 1     225
# 2     150
# 3      89
# 4      80
# 5     200
# 6      60
# 7      79
# 8      79
# 9     150
# 10    135
# 11     85
# 12     89
# 13     85
# 14    120
# 15    140
# 16    215
# 17    140
# 18     99
# 19    190
# 20    299
# Name: price, dtype: int64

# %%
#ou
#data_preco= data['price']
#display(data_preco)
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
#media de aluguel da cidade de Nova York
media = np.mean(data_aluguel_preco)
print(f'A média de preços de aluguéis da cidade de Nova York é de: U$ {media:.2f} ')
# Out:
# A média de preços de aluguéis da cidade de Nova York é de: U$ 136.10

# %% [markdown]
#  Contar todos os nomes distintos que aparecem na coluna região.

# %%
#selecionar a coluna regiao
data_regiao_ny = data.loc[:,'neighbourhood_group']
display(data_regiao_ny)
# Out:
# 0         Brooklyn
# 1        Manhattan
# 2        Manhattan
# 3         Brooklyn
# 4        Manhattan
#            ...
# 48890     Brooklyn
# 48891     Brooklyn
# 48892    Manhattan
# 48893    Manhattan
# 48894    Manhattan
# Name: neighbourhood_group, Length: 48895, dtype: object

# %%
#ou
#data_regiao= data['neighbourhood_group']
#display(data_regiao)

# %%
#o metodo unique, conta valores unicos, ou seja nao repetidos de um dataset, eh um metodo do pandas, vc passa seu dataset filtrado de preferencia como parametro da funçao
#e trnaforma em array!
regioes_unicas_ny = pd.unique(data_regiao_ny)
print(regioes_unicas_ny)
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']

# %% [markdown]
# Qual o valor do aluguel diário mais caro da cidade de Nova York?

# %%
data_alugueis_precos= data.loc[:, 'price']
print(data_alugueis_precos)
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
#encontrar o maior valor
maior_valor = np.max(data_alugueis_precos)
print(f'O maior valor do aluguel da cidade de Nova York é de: U$ {maior_valor:.2f}')
# Out:
# O maior valor do aluguel da cidade de Nova York é de: U$ 10000.00
