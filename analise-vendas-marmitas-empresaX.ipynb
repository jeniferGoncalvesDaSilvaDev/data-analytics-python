# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/data-analytics-python/blob/master/analise-vendas-marmitas-empresaX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sys import breakpointhook
#analise e visualizaçao de dados de vendas diarias de marmitas da empresa x
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
vendas_primeira_semana =[]
vendas_segunda_semana=[]
vendas_terceira_semana=[]
vendas_quarta_semana=[]
dias_da_primeira_semana=[]
dias_da_segunda_semana=[]
dias_da_terceira_semana=[]
dias_quarta_semana=[]
media_primeiro_mes=[]
def numero_marmitas_semana_01():
 try:

  for item in range(0,5):
    item = int(input("Digite o numero de marmitas vendidas, durante a primeira semana: "))
    vendas_primeira_semana.append(item)
  print(vendas_primeira_semana)



 except:
  print("Dado inválido")
def dias_da_semana_01():
  for dia in range(0,5):
      dia = str(input('Digite o dia da semana:'))
      if dia!= 'segunda' and dia!='terça' and dia!='quarta' and dia!='quinta' and dia!='sexta':
        print("Dia inválido!")
        break
      else:
        dias_da_primeira_semana.append(dia)
        print(dias_da_primeira_semana)



#chamando as funções
numero_marmitas_semana_01()
dias_da_semana_01()
# Out:
# Digite o numero de marmitas vendidas, durante a primeira semana: 40
# Digite o numero de marmitas vendidas, durante a primeira semana: 39
# Digite o numero de marmitas vendidas, durante a primeira semana: 41
# Digite o numero de marmitas vendidas, durante a primeira semana: 39
# Digite o numero de marmitas vendidas, durante a primeira semana: 40
# [40, 39, 41, 39, 40]
# Digite o dia da semana:segunda
# ['segunda']
# Digite o dia da semana:terça
# ['segunda', 'terça']
# Digite o dia da semana:quarta
# ['segunda', 'terça', 'quarta']
# Digite o dia da semana:quinta
# ['segunda', 'terça', 'quarta', 'quinta']
# Digite o dia da semana:sexta
# ['segunda', 'terça', 'quarta', 'quinta', 'sexta']

# %%
dias_da_segunda_semana=[]
vendas_segunda_semana=[]
def numero_marmitas_semana_02():
 try:

  for item in range(0,5):
    item = int(input("Digite o numero de marmitas vendidas, durante a segunda semana: "))
    vendas_segunda_semana.append(item)
  print(vendas_segunda_semana)



 except:
  print("Dado inválido")

def dias_da_semana_02():
  for dia in range(0,5):
      dia = str(input('Digite o dia da semana:'))
      if dia!= 'segunda' and dia!='terça' and dia!='quarta' and dia!='quinta' and dia!='sexta':
        print("Dia inválido!")
        break
      else:
        dias_da_segunda_semana.append(dia)
        print(dias_da_segunda_semana)





#chamando as funçoes
numero_marmitas_semana_02()
dias_da_semana_02()
# Out:
# Digite o numero de marmitas vendidas, durante a segunda semana: 36
# Digite o numero de marmitas vendidas, durante a segunda semana: 39
# Digite o numero de marmitas vendidas, durante a segunda semana: 40
# Digite o numero de marmitas vendidas, durante a segunda semana: 41
# Digite o numero de marmitas vendidas, durante a segunda semana: 40
# [36, 39, 40, 41, 40]
# Digite o dia da semana:segunda
# ['segunda']
# Digite o dia da semana:terça
# ['segunda', 'terça']
# Digite o dia da semana:quarta
# ['segunda', 'terça', 'quarta']
# Digite o dia da semana:quinta
# ['segunda', 'terça', 'quarta', 'quinta']
# Digite o dia da semana:sexta
# ['segunda', 'terça', 'quarta', 'quinta', 'sexta']

# %% [markdown]
# Visualização de dados em grafico

# %%
vendas_terceira_semana=[]
dias_da_terceira_semana=[]
def numero_marmitas_semana_03():
 try:

  for item in range(0,4):
    item = int(input("Digite o numero de marmitas vendidas, durante a terceira semana: "))
    vendas_terceira_semana.append(item)
  print(vendas_terceira_semana)



 except:
  print("Dado inválido")
def dias_da_semana_03():
  for dia in range(0,4):
      dia = str(input('Digite o dia da semana:'))
      if dia!= 'segunda' and dia!='terça' and dia!='quarta' and dia!='quinta' and dia!='sexta':
        print("Dia inválido!")
        break
      else:
        dias_da_terceira_semana.append(dia)
        print(dias_da_terceira_semana)


numero_marmitas_semana_03()
dias_da_semana_03()
# Out:
# Digite o numero de marmitas vendidas, durante a terceira semana: 40
# Digite o numero de marmitas vendidas, durante a terceira semana: 36
# Digite o numero de marmitas vendidas, durante a terceira semana: 30
# Digite o numero de marmitas vendidas, durante a terceira semana: 15
# [40, 36, 30, 15]
# Digite o dia da semana:segunda
# ['segunda']
# Digite o dia da semana:terça
# ['segunda', 'terça']
# Digite o dia da semana:quarta
# ['segunda', 'terça', 'quarta']
# Digite o dia da semana:sexta
# ['segunda', 'terça', 'quarta', 'sexta']

# %%
vendas_quarta_semana=[]
dias_da_quarta_semana=[]
def numero_marmitas_semana_04():
 try:

   for item in range(0,5):
     item = int(input("Digite o numero de marmitas vendidas, durante a quarta semana: "))
     vendas_quarta_semana.append(item)
   print(vendas_quarta_semana)



 except:
  print("Dado inválido")
def dias_da_semana_04():
  for dia in range(0,5):
      dia = str(input('Digite o dia da semana:'))
      if dia!= 'segunda' and dia!='terça' and dia!='quarta' and dia!='quinta' and dia!='sexta':
        print("Dia inválido!")
        break
      else:
        dias_da_quarta_semana.append(dia)
        print(dias_da_quarta_semana)


numero_marmitas_semana_04()
dias_da_semana_04()
# Out:
# Digite o numero de marmitas vendidas, durante a quarta semana: 40
# Digite o numero de marmitas vendidas, durante a quarta semana: 41
# Digite o numero de marmitas vendidas, durante a quarta semana: 42
# Digite o numero de marmitas vendidas, durante a quarta semana: 39
# Digite o numero de marmitas vendidas, durante a quarta semana: 39
# [40, 41, 42, 39, 39]
# Digite o dia da semana:segunda
# ['segunda']
# Digite o dia da semana:terça
# ['segunda', 'terça']
# Digite o dia da semana:quarta
# ['segunda', 'terça', 'quarta']
# Digite o dia da semana:quinta
# ['segunda', 'terça', 'quarta', 'quinta']
# Digite o dia da semana:sexta
# ['segunda', 'terça', 'quarta', 'quinta', 'sexta']

# %%
vendas_quinta_semana=[]
dias_da_quinta_semana=[]
def numero_marmitas_semana_05():
 try:

   for item in range(0,4):
     item = int(input("Digite o numero de marmitas vendidas, durante a quinta semana: "))
     vendas_quinta_semana.append(item)
   print(vendas_quinta_semana)



 except:
  print("Dado inválido")
def dias_da_semana_05():
  for dia in range(0,4):
      dia = str(input('Digite o dia da semana:'))
      if dia!= 'segunda' and dia!='terça' and dia!='quarta' and dia!='quinta' and dia!='sexta':
        print("Dia inválido!")
        break
      else:
        dias_da_quinta_semana.append(dia)
        print(dias_da_quinta_semana)
numero_marmitas_semana_05()
dias_da_semana_05()
# Out:
# Digite o numero de marmitas vendidas, durante a quinta semana: 36
# Digite o numero de marmitas vendidas, durante a quinta semana: 40
# Digite o numero de marmitas vendidas, durante a quinta semana: 38
# Digite o numero de marmitas vendidas, durante a quinta semana: 35
# [36, 40, 38, 35]
# Digite o dia da semana:segunda
# ['segunda']
# Digite o dia da semana:terça
# ['segunda', 'terça']
# Digite o dia da semana:quarta
# ['segunda', 'terça', 'quarta']
# Digite o dia da semana:sexta
# ['segunda', 'terça', 'quarta', 'sexta']

# %%
vendas_sexta_semana=[]
dias_da_sexta_semana=[]
def numero_marmitas_semana_06():
 try:

   for item in range(0,4):
     item = int(input("Digite o numero de marmitas vendidas, durante a sexta semana: "))
     vendas_sexta_semana.append(item)
   print(vendas_sexta_semana)



 except:
  print("Dado inválido")
def dias_da_semana_06():
  for dia in range(0,4):
      dia = str(input('Digite o dia da semana:'))
      if dia!= 'segunda' and dia!='terça' and dia!='quarta' and dia!='quinta' and dia!='sexta':
        print("Dia inválido!")
        break
      else:
        dias_da_sexta_semana.append(dia)
        print(dias_da_sexta_semana)
numero_marmitas_semana_06()
dias_da_semana_06()
# Out:
# Digite o numero de marmitas vendidas, durante a quinta semana: 38
# Digite o numero de marmitas vendidas, durante a quinta semana: 39
# Digite o numero de marmitas vendidas, durante a quinta semana: 36
# Digite o numero de marmitas vendidas, durante a quinta semana: 41
# [38, 39, 36, 41]
# Digite o dia da semana:segunda
# ['segunda']
# Digite o dia da semana:terça
# ['segunda', 'terça']
# Digite o dia da semana:quarta
# ['segunda', 'terça', 'quarta']
# Digite o dia da semana:quinta
# ['segunda', 'terça', 'quarta', 'quinta']

# %%
vendas_setima_semana=[]
dias_da_setima_semana=[]
def numero_marmitas_semana_07():
 try:

   for item in range(0,5):
     item = int(input("Digite o numero de marmitas vendidas, durante a setima semana: "))
     vendas_setima_semana.append(item)
   print(vendas_setima_semana)



 except:
  print("Dado inválido")
def dias_da_semana_07():
  for dia in range(0,5):
      dia = str(input('Digite o dia da semana:'))
      if dia!= 'segunda' and dia!='terça' and dia!='quarta' and dia!='quinta' and dia!='sexta':
        print("Dia inválido!")
        break
      else:
        dias_da_setima_semana.append(dia)
        print(dias_da_setima_semana)
numero_marmitas_semana_07()
dias_da_semana_07()
# Out:
# Digite o numero de marmitas vendidas, durante a setima semana: 42
# Digite o numero de marmitas vendidas, durante a setima semana: 40
# Digite o numero de marmitas vendidas, durante a setima semana: 41
# Digite o numero de marmitas vendidas, durante a setima semana: 38
# Digite o numero de marmitas vendidas, durante a setima semana: 40
# [42, 40, 41, 38, 40]
# Digite o dia da semana:segunda
# ['segunda']
# Digite o dia da semana:terça
# ['segunda', 'terça']
# Digite o dia da semana:quarta
# ['segunda', 'terça', 'quarta']
# Digite o dia da semana:quinta
# ['segunda', 'terça', 'quarta', 'quinta']
# Digite o dia da semana:sexta
# ['segunda', 'terça', 'quarta', 'quinta', 'sexta']

# %%
media_primeiro_mes=[]
i=0
def media_mes_01():
  soma_01=np.sum(vendas_primeira_semana)
  soma_02=np.sum(vendas_segunda_semana)
  soma_03=np.sum(vendas_terceira_semana)
  soma_04=np.sum(vendas_quarta_semana)
  #print(soma_01, soma_02, soma_03, soma_04)
  for i in range(0,1):
    media_primeiro_mes.append(soma_01)
    media_primeiro_mes.append(soma_02)
    media_primeiro_mes.append(soma_03)
    media_primeiro_mes.append(soma_04)
  print('soma de marmitas da primeira semana a quarta semana de primeiro mes')
  print(media_primeiro_mes)
  media_01=np.mean(media_primeiro_mes)
  print(f'No primeiro mes de vendas, a média foi de: {media_01:.1f} marmitas vendidas')



media_mes_01()
# Out:
# soma de marmitas da primeira semana a quarta semana de primeiro mes
# [199, 196, 121, 201]
# No primeiro mes de vendas, a média foi de: 179.2 marmitas vendidas

# %%
figura = plt.figure(figsize=(60,10))
figura.suptitle('Análise de vendas de marmitas da empresa x')
figura.add_subplot(131)
plt.plot(dias_da_primeira_semana, vendas_primeira_semana, label= "Vendas diárias de marmitas na primeira semana")
plt.title("Vendas de marmitas na primeira semana ")
plt.legend()
plt.yticks([40,41,39])
plt.ylabel("Número de marmitas vendidas para a empresa x")
plt.xlabel("Dias da semana")
figura.add_subplot(132)
plt.plot(dias_da_segunda_semana, vendas_segunda_semana, label="Vendas diárias de marmitas na segunda semana",color="green")
plt.legend()
plt.yticks([32,38,39,40])
plt.ylabel("Número de marmitas vendidas para a empresa x")
plt.xlabel("Dias da semana")
figura.add_subplot(133)
plt.plot(dias_da_terceira_semana, vendas_terceira_semana, label="Vendas diárias de marmitas na terçeira semana", color="red")
plt.legend()
plt.yticks([15,33,36,40])
plt.ylabel("Número de marmitas vendidas para a empresa x")
plt.xlabel("Dias da semana")
# Out:
# Text(0.5, 0, 'Dias da semana')

# %%
figura2=plt.figure(figsize=(60,10))
figura2.suptitle('Análise de vendas de marmitas da empresa x')
figura2.add_subplot(121)
plt.plot(dias_da_quarta_semana, vendas_quarta_semana, label="Vendas diárias de marmitas na quarta semana", color="black")
plt.legend()
plt.yticks([39,40,41,42])
plt.xlabel('Dias da semana')
plt.ylabel('Número de marmitas vendidas')
figura2.add_subplot(122)
plt.plot(dias_da_quinta_semana, vendas_quinta_semana, label="Vendas diárias de marmitas na quinta semana", color="purple")
plt.legend()
plt.yticks([36,38,40])
# Out:
# ([<matplotlib.axis.YTick at 0x7e9c927fe950>,
# ...
#  [Text(0, 36, '36'), Text(0, 38, '38'), Text(0, 40, '40')])

# %%
figura3=plt.figure(figsize=(60,10))
figura3.suptitle("Análise de vendas de marmitas da empresa x")
figura3.add_subplot(121)
plt.plot(dias_da_sexta_semana, vendas_sexta_semana, label="Vendas diárias de marmitas na sexta semana", color="darkgreen")
plt.legend()
plt.yticks([36,38,39,41])
plt.xlabel('Dias da semana')
plt.ylabel('Número de marmitas vendidas')
figura3.add_subplot(122)
plt.plot(dias_da_setima_semana, vendas_setima_semana, label="Vendas diárias de marmitas na setima semana", color="darkorange")
plt.legend()
plt.yticks([38,40,41,42])
plt.xlabel('Dias da semana')
plt.ylabel('Número de marmitas vendidas')
# Out:
# Text(0, 0.5, 'Número de marmitas vendidas')
