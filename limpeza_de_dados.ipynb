# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/data-analytics-python/blob/master/limpeza_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/train.csv')
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
display(df.head(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
print(df.shape)
print(df.describe())
print(df.info())
# Out:
# (891, 12)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
#valores unicos-cardinalidade
print(df.nunique())
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
embarque_vazio = df.loc[61:829,'Embarked']
display(embarque_vazio)
# Out:
# 61     NaN
# 62       S
# 63       S
# 64       C
# 65       C
#       ...
# 825      Q
# 826      S
# 827      C
# 828      Q
# 829    NaN
# Name: Embarked, Length: 769, dtype: object

# %%
embarque= df[df.Embarked.isnull()]
display(embarque)
#verificando registros com embarque vazio
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
embarcado=df.loc[df.Embarked.isnull(), 'Embarked']='s'
display(embarcado)
# Out:
# 's'

# %%
embarcado = df.loc[61:829, 'Embarked']
display(embarcado)
# Out:
# 61     s
# 62     S
# 63     S
# 64     C
# 65     C
#       ..
# 825    Q
# 826    S
# 827    C
# 828    Q
# 829    s
# Name: Embarked, Length: 769, dtype: object

# %%
idade = df[df.Age.isnull()]
display(idade)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
idade_mostrar = idade['Age']
display(idade_mostrar)
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
#        ..
# 859   NaN
# 863   NaN
# 868   NaN
# 878   NaN
# 888   NaN
# Name: Age, Length: 177, dtype: float64

# %%
print(idade.shape)
# Out:
# (177, 12)

# %%
idade.describe()
# Out:
#        PassengerId    Survived      Pclass  Age       SibSp       Parch  \
# count   177.000000  177.000000  177.000000  0.0  177.000000  177.000000
# mean    435.581921    0.293785    2.598870  NaN    0.564972    0.180791
# std     250.552901    0.456787    0.763216  NaN    1.626316    0.534145
# min       6.000000    0.000000    1.000000  NaN    0.000000    0.000000
# 25%     230.000000    0.000000    3.000000  NaN    0.000000    0.000000
# 50%     452.000000    0.000000    3.000000  NaN    0.000000    0.000000
# 75%     634.000000    1.000000    3.000000  NaN    0.000000    0.000000
# max     889.000000    1.000000    3.000000  NaN    8.000000    2.000000
#
#              Fare
# count  177.000000
# mean    22.158567
# std     31.874608
# min      0.000000
# 25%      7.750000
# 50%      8.050000
# 75%     24.150000
# max    227.525000

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.Age.plot.box()
#verificandi a distribuição da idade
# Out:
# <Axes: >

# %%
df.Age.hist(bins=20)
#o argumento bins, ajusta as linhas do histograma
# Out:
# <Axes: >

# %%
media = df.Age.median()
display(media)
# Out:
# 28.0

# %%
#agrupar por classes
idade_classe = df[['Age', 'Pclass']]
display(idade_classe)
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
idade_classe.nunique()
# Out:
# Age       88
# Pclass     3
# dtype: int64

# %%
classe_agrupada = idade_classe.groupby('Pclass').median()
display(classe_agrupada)
# Out:
#          Age
# Pclass
# 1       37.0
# 2       29.0
# 3       24.0

# %%
classe_agrupada2 = idade_classe.groupby('Pclass').mean()
display(classe_agrupada2)
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
classe_idade_genero = df[['Age', 'Pclass', 'Sex']]
display(classe_idade_genero)
# Out:
#       Age  Pclass     Sex
# 0    22.0       3    male
# 1    38.0       1  female
# 2    26.0       3  female
# 3    35.0       1  female
# 4    35.0       3    male
# ..    ...     ...     ...
# 886  27.0       2    male
# 887  19.0       1  female
# 888   NaN       3  female
# 889  26.0       1    male
# 890  32.0       3    male
#
# [891 rows x 3 columns]

# %%
classe_agrupada3 =classe_idade_genero.groupby(['Pclass', 'Sex']).median()
display(classe_agrupada3)
# Out:
#                 Age
# Pclass Sex
# 1      female  35.0
#        male    40.0
# 2      female  28.0
#        male    30.0
# 3      female  21.5
#        male    25.0

# %%
#criando uma novo coluna para idade
age_check=df['Age Check']=classe_idade_genero.groupby(['Pclass', 'Sex']).transform('median')
display(age_check)
# Out:
#       Age
# 0    25.0
# 1    35.0
# 2    21.5
# 3    35.0
# 4    25.0
# ..    ...
# 886  30.0
# 887  35.0
# 888  21.5
# 889  40.0
# 890  25.0
#
# [891 rows x 1 columns]

# %%
display(df.head(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age Check
# 0      0         A/5 21171   7.2500   NaN        S       25.0
# 1      0          PC 17599  71.2833   C85        C       35.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       21.5

# %%
age_check2  = df.loc[df.Age.isnull(), ['Age']]
display(age_check2)
# Out:
#      Age
# 5    NaN
# 17   NaN
# 19   NaN
# 26   NaN
# 28   NaN
# ..   ...
# 859  NaN
# 863  NaN
# 868  NaN
# 878  NaN
# 888  NaN
#
# [177 rows x 1 columns]

# %%
vazio =df['Age Check 2']
display(vazio.head(20))
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5     25.0
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17    30.0
# 18     NaN
# 19    21.5
# Name: Age Check 2, dtype: float64

# %%
vazio.isnull().sum()
# Out:
# 714

# %%
mediana_idade = classe_idade_genero.groupby(['Pclass', 'Sex']).transform('median')
display(mediana_idade)
# Out:
#       Age
# 0    25.0
# 1    35.0
# 2    21.5
# 3    35.0
# 4    25.0
# ..    ...
# 886  30.0
# 887  35.0
# 888  21.5
# 889  40.0
# 890  25.0
#
# [891 rows x 1 columns]

# %%
df.drop(columns = 'Age Check 2')
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Mediana Idade']= classe_idade_genero.groupby(['Pclass', 'Sex']).transform('median')
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
age_check2  = df.loc[df.Age.isnull(), ['Age']]
display(age_check2)
# Out:
#      Age
# 5    NaN
# 17   NaN
# 19   NaN
# 26   NaN
# 28   NaN
# ..   ...
# 859  NaN
# 863  NaN
# 868  NaN
# 878  NaN
# 888  NaN
#
# [177 rows x 1 columns]

# %%
remover =df.loc[:, ['Age Check 2']]
display(remover)
# Out:
#      Age Check 2
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 886          NaN
# 887          NaN
# 888         21.5
# 889          NaN
# 890          NaN
#
# [891 rows x 1 columns]

# %%
df['Age Check 2'] = remover.dropna(how='all')

# %%
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
